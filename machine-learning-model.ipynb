# %%
import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
merged_df = pd.read_csv('Resources/Final_Merge2.csv')

# %%
merged_df.head(20)
# Out:
#     Unnamed: 0  NPA  year                                    Petitioner  \
# 0            0    2  2020                    Alenky Signature Homes LLC
# 1            1    2  2019                                   Mark Heisig
# 2            2    2  2014                      Eastway II Holdings, LLC
# 3            3    2  2014                      Eastway II Holdings, LLC
# 4            4    2  2016                     Dr. Michael Berglass, DDS
# 5            5    3  2015                               1700 South, LLC
# 6            6    3  2019  The Charlotte-Mecklenburg Hospital Authority
# 7            7    3  2017                                 ABW Charlotte
# 8            8    3  2016                         Rockwell Capital, LLC
# 9            9    3  2015            Meeting Street Homes & Communities
# 10          10    3  2014                            Golden Triangle #2
# 11          11    3  2014                              Weekley Homes LP
# 12          12    3  2014                  Marsh Euclid Apartments, LLC
# 13          13    3  2014                              Weekley Homes LP
# 14          14    3  2015            Meeting Street Homes & Communities
# 15          15    3  2018                     Suncap Property Group LLC
# 16          16    3  2019                     White Point Partners, LLC
# 17          17    3  2014           New Carolina Income Properties, LLC
# 18          18    3  2014                        Pulte Home Corporation
# 19          19    3  2017                                 ABW Charlotte
#
#     FromZone     ToZone Type  SPA INNOV   Acres  ... student_absenteeism  \
# 0        R-4        R-8   NC   no    NO   0.398  ...                 NaN
# 1        O-2        R-4   NC   no    NO   0.330  ...                 NaN
# 2     BD(CD)     BD(CD)   CD  SPA    NO   3.050  ...           11.500000
# 3     B-1SCD     BD(CD)   CD   no    NO   3.740  ...           11.500000
# 4   UR-C(CD)   UR-C(CD)   CD  SPA    NO   0.440  ...           15.000000
# 5        B-1      TOD-M   NC   no    NO   0.260  ...            5.721393
# 6        B-1     MUDD-O   CD   no    NO  70.530  ...                 NaN
# 7      TOD-M   TOD-M(O)   CD   no    NO   0.529  ...            5.000000
# 8        B-2   UR-3(CD)   CD   no    NO   2.710  ...            6.000000
# 9     R-22MF   MUDD(CD)   CD   no    NO   0.419  ...            5.721393
# 10    MUDD-O     MUDD-O   CD  SPA    NO   1.300  ...            5.673759
# 11       R-5   UR-2(CD)   CD   no    NO   1.020  ...            5.673759
# 12       O-2     TOD-MO   CD  SPA    NO   2.990  ...            5.673759
# 13  MUDD(CD)   UR-2(CD)   CD   no    NO   1.020  ...            5.673759
# 14       B-1   MUDD(CD)   CD   no    NO   0.419  ...            5.721393
# 15       R-8    R-8(CD)   CD   no    NO   1.750  ...                 NaN
# 16       B-1     TOD-UC   NC   no    NO   1.200  ...                 NaN
# 17  UR-2(CD)  TOD-R(CD)   CD   no    NO   0.400  ...            5.673759
# 18       B-2   UR-2(CD)   CD   no    NO   2.910  ...            5.673759
# 19       B-1   TOD-M(O)   CD   no    NO   0.529  ...            5.000000
#
#    voters_participating neighborhood_organizations voter_participation  \
# 0                   NaN                        NaN                 NaN
# 1                   NaN                        NaN                 NaN
# 2                 603.0                        2.0                54.0
# 3                 603.0                        2.0                54.0
# 4                1063.0                        NaN                76.0
# 5                1354.0                        7.0                24.0
# 6                   NaN                        NaN                 NaN
# 7                1736.0                        NaN                25.0
# 8                5386.0                        NaN                76.0
# 9                1354.0                        7.0                24.0
# 10               2787.0                        7.0                53.0
# 11               2787.0                        7.0                53.0
# 12               2787.0                        7.0                53.0
# 13               2787.0                        7.0                53.0
# 14               1354.0                        7.0                24.0
# 15               3991.0                        NaN                67.0
# 16                  NaN                        NaN                 NaN
# 17               2787.0                        7.0                53.0
# 18               2787.0                        7.0                53.0
# 19               1736.0                        NaN                25.0
#
#    vacant_land population_density population transit_ridership  \
# 0          NaN                NaN        NaN               NaN
# 1          NaN                NaN        NaN               NaN
# 2          NaN                NaN        NaN              43.0
# 3          NaN                NaN        NaN              43.0
# 4          4.3                5.0     2240.0               NaN
# 5          2.5                7.0     7938.0              34.0
# 6          NaN                NaN        NaN               NaN
# 7          2.4                8.0     8816.0               NaN
# 8          2.4                7.0     7986.0               NaN
# 9          2.5                7.0     7938.0              34.0
# 10         NaN                NaN        NaN              35.0
# 11         NaN                NaN        NaN              35.0
# 12         NaN                NaN        NaN              35.0
# 13         NaN                NaN        NaN              35.0
# 14         2.5                7.0     7938.0              34.0
# 15         2.4                8.0     9758.0               NaN
# 16         NaN                NaN        NaN               NaN
# 17         NaN                NaN        NaN              35.0
# 18         NaN                NaN        NaN              35.0
# 19         2.4                8.0     8816.0               NaN
#
#    street_connectivity bicycle_friendliness
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4                 1.20                  1.5
# 5                 1.50                  2.1
# 6                  NaN                  NaN
# 7                 1.48                  2.1
# 8                 1.48                  2.2
# 9                 1.50                  2.1
# 10                 NaN                  NaN
# 11                 NaN                  NaN
# 12                 NaN                  NaN
# 13                 NaN                  NaN
# 14                1.50                  2.1
# 15                1.48                  2.1
# 16                 NaN                  NaN
# 17                 NaN                  NaN
# 18                 NaN                  NaN
# 19                1.48                  2.1
#
# [20 rows x 45 columns]

# %%
column_names = list(merged_df.columns.values)
print(column_names)
# Out:
# ['Unnamed: 0', 'NPA', 'year', 'Petitioner', 'FromZone', 'ToZone', 'Type', 'SPA', 'INNOV', 'Acres', 'Water', 'Sewer', 'CityLimit', 'CCW', 'ServiceArea', 'LuseStaff', 'UrbanDesign', 'RezoneStaff', 'Received', 'Approved', 'Decision', 'births_to_adolescents', 'grocery_proximate_units', 'prenatal_care', 'grocery_proximity', 'low_birthweight', 'public_health_insurance', 'age_of_death', 'impervious_surface', 'water_consumption', 'neighborhood_school_attendance', 'highschool_graduation_rate', 'proficiency_elementary_school', 'proficiency_middle_school', 'proficiency_high_school', 'student_absenteeism', 'voters_participating', 'neighborhood_organizations', 'voter_participation', 'vacant_land', 'population_density', 'population', 'transit_ridership', 'street_connectivity', 'bicycle_friendliness']

# %%
types = list(merged_df.dtypes.values)
print(types)
# Out:
# [dtype('int64'), dtype('int64'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('float64'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64'), dtype('float64')]

# %%
column_df = {'column_name':column_names,'data_type':types}
column_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-196f5aa09709> in <module>
#       1 column_df = {'column_name':column_names,'data_type':types}
# ----> 2 column_df.head()
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
# Set the seed value for the notebook so the results are reproducible
from numpy.random import seed
seed(1)

# %%
# Dependencies
import numpy as np
import pandas as pd

# %%
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.2.4-tf'

# %%
requests_data = pd.read_csv('../Resources/voice.csv')
voice.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000   male
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632   male
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512   male
# 3  0.250000  0.201497  0.007812  0.562500  0.554688  0.247119   male
# 4  0.266667  0.712812  0.007812  5.484375  5.476562  0.208274   male
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Data Pre-Processing

# %%
X = requests_data.drop("Decision", axis=1)
y = requests_data["Decision"]
print(X.shape, y.shape)
# Out:
# (3168, 20) (3168,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1)

# %%
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# # Create a Deep Learning Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Create model and add layers
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=20))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %%
# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               2100
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 12,402
# Trainable params: 12,402
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 2376 samples
# Epoch 1/60
# 2376/2376 - 1s - loss: 0.4958 - accuracy: 0.8089
# Epoch 2/60
# 2376/2376 - 0s - loss: 0.2202 - accuracy: 0.9276
# Epoch 3/60
# 2376/2376 - 0s - loss: 0.1248 - accuracy: 0.9638
# Epoch 4/60
# 2376/2376 - 0s - loss: 0.0991 - accuracy: 0.9680
# Epoch 5/60
# 2376/2376 - 0s - loss: 0.0994 - accuracy: 0.9701
# Epoch 6/60
# 2376/2376 - 0s - loss: 0.0989 - accuracy: 0.9693
# Epoch 7/60
# 2376/2376 - 0s - loss: 0.0841 - accuracy: 0.9743
# Epoch 8/60
# 2376/2376 - 0s - loss: 0.0817 - accuracy: 0.9760
# Epoch 9/60
# 2376/2376 - 0s - loss: 0.0779 - accuracy: 0.9773
# Epoch 10/60
# 2376/2376 - 0s - loss: 0.0756 - accuracy: 0.9773
# Epoch 11/60
# 2376/2376 - 0s - loss: 0.0752 - accuracy: 0.9773
# Epoch 12/60
# 2376/2376 - 0s - loss: 0.0783 - accuracy: 0.9764
# Epoch 13/60
# 2376/2376 - 0s - loss: 0.0742 - accuracy: 0.9777
# Epoch 14/60
# 2376/2376 - 0s - loss: 0.0745 - accuracy: 0.9760
# Epoch 15/60
# 2376/2376 - 0s - loss: 0.0746 - accuracy: 0.9735
# Epoch 16/60
# 2376/2376 - 0s - loss: 0.0733 - accuracy: 0.9760
# Epoch 17/60
# 2376/2376 - 0s - loss: 0.0701 - accuracy: 0.9798
# Epoch 18/60
# 2376/2376 - 0s - loss: 0.0728 - accuracy: 0.9764
# Epoch 19/60
# 2376/2376 - 0s - loss: 0.0667 - accuracy: 0.9794
# Epoch 20/60
# 2376/2376 - 0s - loss: 0.0692 - accuracy: 0.9769
# Epoch 21/60
# 2376/2376 - 0s - loss: 0.0658 - accuracy: 0.9790
# Epoch 22/60
# 2376/2376 - 0s - loss: 0.0657 - accuracy: 0.9777
# Epoch 23/60
# 2376/2376 - 0s - loss: 0.0601 - accuracy: 0.9794
# Epoch 24/60
# 2376/2376 - 0s - loss: 0.0642 - accuracy: 0.9777
# Epoch 25/60
# 2376/2376 - 0s - loss: 0.0651 - accuracy: 0.9794
# Epoch 26/60
# 2376/2376 - 0s - loss: 0.0607 - accuracy: 0.9802
# Epoch 27/60
# 2376/2376 - 0s - loss: 0.0595 - accuracy: 0.9823
# Epoch 28/60
# 2376/2376 - 0s - loss: 0.0577 - accuracy: 0.9819
# Epoch 29/60
# 2376/2376 - 0s - loss: 0.0667 - accuracy: 0.9764
# Epoch 30/60
# 2376/2376 - 0s - loss: 0.0607 - accuracy: 0.9790
# Epoch 31/60
# 2376/2376 - 0s - loss: 0.0579 - accuracy: 0.9815
# Epoch 32/60
# 2376/2376 - 0s - loss: 0.0563 - accuracy: 0.9815
# Epoch 33/60
# 2376/2376 - 0s - loss: 0.0553 - accuracy: 0.9811
# Epoch 34/60
# 2376/2376 - 0s - loss: 0.0558 - accuracy: 0.9806
# Epoch 35/60
# 2376/2376 - 0s - loss: 0.0562 - accuracy: 0.9802
# Epoch 36/60
# 2376/2376 - 0s - loss: 0.0526 - accuracy: 0.9827
# Epoch 37/60
# 2376/2376 - 0s - loss: 0.0588 - accuracy: 0.9802
# Epoch 38/60
# 2376/2376 - 0s - loss: 0.0552 - accuracy: 0.9815
# Epoch 39/60
# 2376/2376 - 0s - loss: 0.0523 - accuracy: 0.9827
# Epoch 40/60
# 2376/2376 - 0s - loss: 0.0522 - accuracy: 0.9815
# Epoch 41/60
# 2376/2376 - 0s - loss: 0.0530 - accuracy: 0.9811
# Epoch 42/60
# 2376/2376 - 0s - loss: 0.0532 - accuracy: 0.9802
# Epoch 43/60
# 2376/2376 - 0s - loss: 0.0499 - accuracy: 0.9840
# Epoch 44/60
# 2376/2376 - 0s - loss: 0.0483 - accuracy: 0.9827
# Epoch 45/60
# 2376/2376 - 0s - loss: 0.0527 - accuracy: 0.9781
# Epoch 46/60
# 2376/2376 - 0s - loss: 0.0513 - accuracy: 0.9815
# Epoch 47/60
# 2376/2376 - 0s - loss: 0.0482 - accuracy: 0.9844
# Epoch 48/60
# 2376/2376 - 0s - loss: 0.0452 - accuracy: 0.9832
# Epoch 49/60
# 2376/2376 - 0s - loss: 0.0604 - accuracy: 0.9794
# Epoch 50/60
# 2376/2376 - 0s - loss: 0.0457 - accuracy: 0.9832
# Epoch 51/60
# 2376/2376 - 0s - loss: 0.0465 - accuracy: 0.9827
# Epoch 52/60
# 2376/2376 - 0s - loss: 0.0492 - accuracy: 0.9819
# Epoch 53/60
# 2376/2376 - 0s - loss: 0.0477 - accuracy: 0.9823
# Epoch 54/60
# 2376/2376 - 0s - loss: 0.0423 - accuracy: 0.9853
# Epoch 55/60
# 2376/2376 - 0s - loss: 0.0478 - accuracy: 0.9823
# Epoch 56/60
# 2376/2376 - 0s - loss: 0.0428 - accuracy: 0.9836
# Epoch 57/60
# 2376/2376 - 0s - loss: 0.0431 - accuracy: 0.9840
# Epoch 58/60
# 2376/2376 - 0s - loss: 0.0466 - accuracy: 0.9832
# Epoch 59/60
# 2376/2376 - 0s - loss: 0.0428 - accuracy: 0.9857
# Epoch 60/60
# 2376/2376 - 0s - loss: 0.0437 - accuracy: 0.9832

# %% [markdown]
# ## Quantify our Trained Model

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 792/1 - 0s - loss: 0.0328 - accuracy: 0.9798
# Normal Neural Network - Loss: 0.05984371190777782, Accuracy: 0.9797979593276978

# %% [markdown]
# ## Make Predictions

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:5])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:5])}")
# Out:
# Predicted classes: ['female' 'female' 'female' 'female' 'female']
# Actual Labels: ['female', 'female', 'female', 'female', 'female']
